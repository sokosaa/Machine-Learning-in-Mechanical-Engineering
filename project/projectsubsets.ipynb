# %% [markdown]
# MEM T380
#
# Case Studies Group 10
#
# Ante Sokosa
# Ziad Hatab
#
# Final Project - Weld Defect Classification with Aritifial Neural Networks

# %%
# for calculating notebook runtime
import time
start_time = time.time()

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import tensorflow as tf
import random

# Set the random seeds
np.random.seed(0)
random.seed(0)
tf.random.set_seed(0)

from keras.models import Sequential, Model
from keras.utils import to_categorical, plot_model
from keras.layers import Input, Dense, concatenate
from keras.wrappers.scikit_learn import KerasClassifier

from keras.optimizers import Adam, SGD, RMSprop
from keras.regularizers import l2
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, KFold, StratifiedKFold
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 1 &nbsp; `Data Exploration (Access, Preprocessimg, and Deriving Features`
#
# Data exploration has been previously explained, discussed, and completed in HW2.
# We are importing this data as explored, cleaned, and prepared with subsets combined.

# %%
excel_file = 'weld_defect_dataset.xlsx'

X_subsets = []
Y_subsets = []

for i in range(1, 6):
    subset = pd.read_excel(excel_file, sheet_name = 'subset' + str(i))
    subset = subset.rename(columns={'Type':'type','W':'w','Ar':'ar','Sp':'sp','Re':'re','Rr':'rr','Sk':'sk','Ku':'ku','Hc':'hc','Rc':'rc','Sc ':'sc','Kc ':'kc'}) 

    # Apply MinMaxScaler on numerical features
    nums = subset.select_dtypes(include=['float64']).columns
    subset[nums] = StandardScaler().fit_transform(subset[nums])

    # Apply One-Hot-Encoding on the target column
    types = subset['type'].unique().tolist()
    cat_type = CategoricalDtype(categories=types, ordered=True)
    subset['type'] = subset['type'].astype(cat_type)
    subset = pd.get_dummies(subset, columns=['type'], prefix=['type'])

    # Separating features (X) and target (Y)
    X = subset.drop(columns=[col for col in subset.columns if 'type' in col]).to_numpy()
    Y = subset[[col for col in subset.columns if 'type' in col]].to_numpy()

    # Store subsets in lists
    X_subsets.append(X)
    Y_subsets.append(Y)

# Y_subsets[0].shape
# X_subsets[0].shape

# %%
# excel_file = 'weld_defect_dataset.xlsx'

# for i in range(1, 6):
#     subset = pd.read_excel(excel_file, sheet_name = 'subset' + str(i))
#     subset = subset.rename(columns={'Type':'type','W':'w','Ar':'ar','Sp':'sp','Re':'re','Rr':'rr','Sk':'sk','Ku':'ku','Hc':'hc','Rc':'rc','Sc ':'sc','Kc ':'kc'}) 

#     # Count the number of each type
#     type_counts = subset['type'].value_counts()
#     print(f"In subset {i}, the type counts are:\n{type_counts}\n")

# %%
# excel_file = 'weld_defect_dataset.xlsx'

# # gather data from excel file
# subsets = []
# for i in range(1, 6):
#     subset = pd.read_excel(excel_file, sheet_name = 'subset' + str(i))
#     subset = subset.rename(columns={'Type':'type','W':'w','Ar':'ar','Sp':'sp','Re':'re','Rr':'rr','Sk':'sk','Ku':'ku','Hc':'hc','Rc':'rc','Sc ':'sc','Kc ':'kc'}) # note the space after Sc and Kc are errors in naming in the excel file and are corrected here for ease of use later
#     subsets.append(subset)
# df = pd.concat(subsets, ignore_index=True)
# df.drop_duplicates(inplace=True)
# df.reset_index(drop=True, inplace=True)

# # Features
# nums = list(df.select_dtypes(include=['float64']).columns)
# df[nums] = MinMaxScaler().fit_transform(df[nums])

# # Target
# types = df['type'].unique().tolist()
# print('types:',types)
# cat_type = CategoricalDtype(categories=types, ordered=True) # specify the order of categories (stop it from going in alphabetical order; good for confusion matricies comparisons to paper later)
# df['type'] = df['type'].astype(cat_type) # convert column to categorical type
# df['type_copy'] = df['type'] # create column for get_dummies() to work on so that we keep the orignal 'type' columns afterwards
# df = pd.get_dummies(df, columns=['type_copy'], prefix=['type']) # get dummies

# excel_file_clean = excel_file.split('.')[0]+'_clean.xlsx'
# df.to_excel(excel_file_clean, index=False)
# # df # clean and prepped dataframe

# %% [markdown]
# For Reference:
#
# `Defect Features:`
#
# ![image.png](attachment:image.png)
#
# `Defect Types:`
# - `PO` = porosity
# - `SL` = slag inclusion
# - `LP` = lack of penetration
# - `LF` = lack of fusion
# - `CR` = crack

# %% [markdown]
# Useing `.info()` and `.describe()` for data confirmation and reference:

# %%
# df.info()

# %%
# df[nums].describe()

# %%
# sns.pairplot(df, vars=nums, hue='type', diag_kind='kde')

# %%
# sns.heatmap(df[nums].corr(), annot=True)

# %% [markdown]
# # 2 &nbsp; `Train`

# %% [markdown]
# We will begin by splitting our data into training and testing sets, using a 20% test size:

# %%
# X = df.select_dtypes(include=['float64']).values
# Y = df.select_dtypes(include=['uint8']).values
# y = df['type'].values
# y = LabelEncoder().fit_transform(y)

# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=42)

# print(f'X_train shape: {X_train.shape} Type: {type(X_train)}')
# print(f'X_test  shape: {X_test.shape}  Type: {type(X_test)}')
# print(f'y_train shape: {Y_train.shape}  Type: {type(Y_train)}')
# print(f'y_test  shape: {Y_test.shape}   Type: {type(Y_test)}')

# n_features = X.shape[1]
# n_classes = Y.shape[1]
# print('number of features: ', n_features)
# print('number of classes : ', n_classes)

# %% [markdown]
# Construct basic artificial neural network (ANN) model with Keras:
#
# explain why relu and sigmoid - sigmoid needed for outet - relu needed earlier due to vanishing gradient problem it does best on (as in reaserch paper)
#
# We will create a functioin of a basic ANN model and then created differenent instances basese on different params, skips, etc.

# %%
def create_keras_model(input_dim=11, output_dim=5, hidden_nodes=[[6, 3], [5, 3], [5, 4]], 
                       optimizer='adam', learning_rate=0.001, regularization_factor=0.01):
    '''
    How to call:
    model_name = create_keras_model(n_features, n_classes, hidden_nodes=[[5, 2], [10, 4], [15, 8]], 
                                    optimizer='adam', learning_rate=0.001, regularization_factor=0.01)
    '''

    # input layer
    inputs = Input(shape=(input_dim,))

    # lists to hold hidden layers
    hidden_layers = []
    compressed_layers = []

    # create hidden layers
    for i in range(len(hidden_nodes)):
        if i == 0:
            # if it's the first hidden layer, connect it to the inputs
            hidden_layers.append(Dense(units=hidden_nodes[i][0], activation='relu', kernel_initializer='random_normal', kernel_regularizer=l2(regularization_factor))(inputs))
        else:
            # otherwise, connect it to the previous hidden layer
            hidden_layers.append(Dense(units=hidden_nodes[i][0], activation='relu', kernel_initializer='random_normal', kernel_regularizer=l2(regularization_factor))(hidden_layers[-1]))
        
        # compression layer
        compressed_layers.append(Dense(units=hidden_nodes[i][1], activation='relu', kernel_initializer='random_normal', kernel_regularizer=l2(regularization_factor))(hidden_layers[-1]))

    # concatenate the compressed layers
    concatenated = concatenate(compressed_layers)

    # output layer, directly connected to the concatenated layer
    outputs = Dense(output_dim, activation='softmax')(concatenated)

    # create model
    model = Model(inputs=inputs, outputs=outputs)

    # define optimizer with the given learning rate
    if optimizer == 'adam':
        optimizer = Adam(learning_rate=learning_rate)
    elif optimizer == 'sgd':
        optimizer = SGD(learning_rate=learning_rate)
    elif optimizer == 'rmsprop':
        optimizer = RMSprop(learning_rate=learning_rate)

    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy']) 

    return model

# model = create_keras_model(hidden_nodes=[[6, 3], [5, 3], [5, 4]],
#                            optimizer='adam', learning_rate=0.001, regularization_factor=0.01)
# model.summary()
# plot_model(model, show_shapes=True)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from keras.callbacks import EarlyStopping

# Create model
model = create_keras_model(hidden_nodes=[[6, 3], [5, 3], [5, 4]], optimizer='adam', learning_rate=0.001, regularization_factor=0.01)

# Combine the first four subsets for training
X_train = np.concatenate(X_subsets[:-1])
Y_train = np.concatenate(Y_subsets[:-1])

# Use the last subset for testing/validation
X_test = X_subsets[-1]
Y_test = Y_subsets[-1]

# Define early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=100)

# Train the model
model_fit = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), verbose=1, batch_size=1, epochs=1000, callbacks=[early_stop])

# Get predictions
Y_pred_train = model.predict(X_train)
Y_pred_test = model.predict(X_test)

# Convert the prediction probabilities into class predictions
y_pred_train = (Y_pred_train > 0.5).astype(int)
y_pred_test = (Y_pred_test > 0.5).astype(int)

# Create confusion matrix and classification report
cm_train = confusion_matrix(Y_train.argmax(axis=1), y_pred_train.argmax(axis=1))
cm_test = confusion_matrix(Y_test.argmax(axis=1), y_pred_test.argmax(axis=1))

print("Confusion matrix (training):")
print(cm_train)
print("\nConfusion matrix (testing):")
print(cm_test)

cr_train = classification_report(Y_train.argmax(axis=1), y_pred_train.argmax(axis=1))
cr_test = classification_report(Y_test.argmax(axis=1), y_pred_test.argmax(axis=1))

print("\nClassification report (training):")
print(cr_train)
print("\nClassification report (testing):")
print(cr_test)
# Out:
# Epoch 1/1000
# 176/176 [==============================] - 2s 5ms/step - loss: 1.5953 - accuracy: 0.2955 - val_loss: 1.5442 - val_accuracy: 0.4318
# Epoch 2/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 1.4451 - accuracy: 0.4375 - val_loss: 1.2899 - val_accuracy: 0.4545
# Epoch 3/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 1.2199 - accuracy: 0.4545 - val_loss: 1.1060 - val_accuracy: 0.4545
# Epoch 4/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 1.1101 - accuracy: 0.4602 - val_loss: 1.0320 - val_accuracy: 0.4545
# Epoch 5/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 1.0475 - accuracy: 0.4602 - val_loss: 0.9797 - val_accuracy: 0.4545
# Epoch 6/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0.9972 - accuracy: 0.5114 - val_loss: 0.9355 - val_accuracy: 0.5227
# Epoch 7/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.9486 - accuracy: 0.5511 - val_loss: 0.8910 - val_accuracy: 0.5909
# Epoch 8/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0.9009 - accuracy: 0.6364 - val_loss: 0.8472 - val_accuracy: 0.6136
# Epoch 9/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.8581 - accuracy: 0.6477 - val_loss: 0.8078 - val_accuracy: 0.7273
# Epoch 10/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.8187 - accuracy: 0.6989 - val_loss: 0.7694 - val_accuracy: 0.7273
# Epoch 11/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.7800 - accuracy: 0.7386 - val_loss: 0.7396 - val_accuracy: 0.7273
# Epoch 12/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0.7510 - accuracy: 0.7898 - val_loss: 0.7159 - val_accuracy: 0.7273
# Epoch 13/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0
1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0.2644 - accuracy: 0.9375 - val_loss: 0.4595 - val_accuracy: 0.8409
# Epoch 192/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2591 - accuracy: 0.9432 - val_loss: 0.4501 - val_accuracy: 0.8182
# Epoch 193/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2622 - accuracy: 0.9545 - val_loss: 0.4560 - val_accuracy: 0.8182
# Epoch 194/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2606 - accuracy: 0.9375 - val_loss: 0.4603 - val_accuracy: 0.8182
# Epoch 195/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2617 - accuracy: 0.9545 - val_loss: 0.4813 - val_accuracy: 0.8182
# Epoch 196/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2606 - accuracy: 0.9318 - val_loss: 0.4760 - val_accuracy: 0.8182
# Epoch 197/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2632 - accuracy: 0.9489 - val_loss: 0.4436 - val_accuracy: 0.8182
# Epoch 198/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2594 - accuracy: 0.9432 - val_loss: 0.4432 - val_accuracy: 0.8182
# Epoch 199/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2592 - accuracy: 0.9489 - val_loss: 0.4587 - val_accuracy: 0.8182
# Epoch 200/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2561 - accuracy: 0.9432 - val_loss: 0.4504 - val_accuracy: 0.8182
# Epoch 201/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2559 - accuracy: 0.9432 - val_loss: 0.4555 - val_accuracy: 0.8182
# Epoch 202/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2577 - accuracy: 0.9432 - val_loss: 0.4723 - val_accuracy: 0.8182
# Epoch 203/1000
# 176/176 [==============================] - 1s 5ms/step - loss: 0.2570 - accuracy: 0.9545 - val_loss: 0.4740 - val_accuracy: 0.8409
# Epoch 204/1000
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2560 - accuracy: 0.9489 - val_loss: 0.4421 - val_accuracy: 0.8182
# Epoch 205/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2533 - accuracy: 0.9489 - val_loss: 0.4837 - val_accuracy: 0.8182
# Epoch 206/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2579 - accuracy: 0.9489 - val_loss: 0.4620 - val_accuracy: 0.8182
# Epoch 207/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2554 - accuracy: 0.9375 - val_loss: 0.4750 - val_accuracy: 0.8182
# Epoch 208/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2547 - accuracy: 0.9489 - val_loss: 0.4742 - val_accuracy: 0.8182
# Epoch 209/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0.2529 - accuracy: 0.9545 - val_loss: 0.5032 - val_accuracy: 0.8409
# Epoch 210/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0.2533 - accuracy: 0.9432 - val_loss: 0.4567 - val_accuracy: 0.8182
# Epoch 211/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0.2519 - accuracy: 0.9545 - val_loss: 0.4760 - val_accuracy: 0.8182
# Epoch 212/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2510 - accuracy: 0.9545 - val_loss: 0.4923 - val_accuracy: 0.8182
# Epoch 213/1000
# 176/176 [==============================] - 0s 3ms/step - loss: 0.2516 - accuracy: 0.9545 - val_loss: 0.4761 - val_accuracy: 0.8409
# Epoch 214/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2537 - accuracy: 0.9489 - val_loss: 0.4714 - val_accuracy: 0.8409
# Epoch 215/1000
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2523 - accuracy: 0.9659 - val_loss: 0.4717 - val_accuracy: 0.8182
# Epoch 216/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2503 - accuracy: 0.9602 - val_loss: 0.4744 - val_accuracy: 0.8182
# Epoch 217/1000
# 176/176 [==============================] - 1s 4ms/step - loss: 0.2522 - accuracy: 0.9489 - val_loss: 0.4835 - val_accuracy: 0.8409
# Epoch 218/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2530 - accuracy: 0.9489 - val_loss: 0.4733 - val_accuracy: 0.8182
# Epoch 219/1000
# 176/176 [==============================] - 1s 3ms/step - loss: 0.2519 - accuracy: 0.9602 - val_loss: 0.4813 - val_accuracy: 0.8182
# 6/6 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 5ms/step
# Confusion matrix (training):
# [[39  1  0  0  0]
#  [ 2 37  0  1  0]
#  [ 0  0 40  0  0]
#  [ 1  2  0 25  0]
#  [ 0  0  0  0 28]]
#
# Confusion matrix (testing):
# [[10  0  0  0  0]
#  [ 2  7  0  1  0]
#  [ 0  0  9  1  0]
#  [ 0  3  0  3  1]
#  [ 0  0  0  0  7]]
#
# Classification report (training):
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95        40
#            1       0.93      0.93      0.93        40
#            2       1.00      1.00      1.00        40
#            3       0.96      0.89      0.93        28
#            4       1.00      1.00      1.00        28
#
#     accuracy                           0.96       176
#    macro avg       0.96      0.96      0.96       176
# weighted avg       0.96      0.96      0.96       176
#
#
# Classification report (testing):
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        10
#            1       0.70      0.70      0.70        10
#            2       1.00      0.90      0.95        10
#            3       0.60      0.43      0.50         7
#            4       0.88      1.00      0.93         7
#
#     accuracy                           0.82        44
#    macro avg       0.80      0.81      0.80        44
# weighted avg       0.81      0.82      0.81        44

# %%
# # Assume your subsets are stored in lists
# # X_subsets is a list of numpy arrays, each containing the features for a subset
# # Y_subsets is a list of numpy arrays, each containing the labels for a subset

# accuracy_scores_train = []
# accuracy_scores_test = []

# # Iterate over each subset
# for i in range(5):
#     # Use the i-th subset as the test set, and all other subsets as the training set
#     X_test = X_subsets[i]
#     Y_test = Y_subsets[i]
#     X_train = np.concatenate([X_subsets[j] for j in range(5) if j != i])
#     Y_train = np.concatenate([Y_subsets[j] for j in range(5) if j != i])
    
#     # The rest of your code remains the same

#     # Define early stopping callback
#     early_stop = EarlyStopping(monitor='val_loss', patience=100)
#     # Train the model
#     model_fit = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), verbose=1, batch_size=1, epochs=1000, callbacks=[early_stop])
    
#     # Test your model's performance on the training and test sets
#     Y_pred_train = model.predict(X_train)
#     Y_pred_test = model.predict(X_test)
    
#     # Convert the prediction probabilities into class predictions
#     y_pred_train = (Y_pred_train > 0.5).astype(int)
#     y_pred_test = (Y_pred_test > 0.5).astype(int)
    
#     # Evaluate the model's performance on the testing set
#     # accuracy_score doesn't work with multilabel output, you need to use some other metric
#     # One possibility is average accuracy per class
#     accuracy_train = np.mean([accuracy_score(Y_train[:, k], y_pred_train[:, k]) for k in range(Y_train.shape[1])])
#     accuracy_test = np.mean([accuracy_score(Y_test[:, k], y_pred_test[:, k]) for k in range(Y_test.shape[1])])
#     accuracy_scores_train.append(accuracy_train)
#     accuracy_scores_test.append(accuracy_test)
    
# # Aggregate the evaluation results across folds
# mean_accuracy_train = np.mean(accuracy_scores_train)
# mean_accuracy_test = np.mean(accuracy_scores_test)
# print(f'Mean training accuracy over 5 folds: {mean_accuracy_train:.6f}')
# print(f'Mean testing accuracy over 5 folds: {mean_accuracy_test:.6f}')

# %%
# kf = KFold(n_splits=5, shuffle=True, random_state=42)

# # Lists to store evaluation results across folds
# accuracy_scores_train = []
# accuracy_scores_test = []

# for train_index, test_index in kf.split(X):
#     X_train, X_test = X[train_index], X[test_index]
#     Y_train, Y_test = Y[train_index], Y[test_index]
    
#     # Define early stopping callback
#     early_stop = EarlyStopping(monitor='val_loss', patience=100)
#     # Train the model
#     model_fit = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), verbose=1, batch_size=1, epochs=1000, callbacks=[early_stop])
    
#     # Test your model's performance on the training and test sets
#     Y_pred_train = model.predict(X_train)
#     Y_pred_test = model.predict(X_test)
    
#     # Convert the prediction probabilities into class predictions
#     y_pred_train = (Y_pred_train > 0.5).astype(int)
#     y_pred_test = (Y_pred_test > 0.5).astype(int)
    
#     # Evaluate the model's performance on the testing set
#     # accuracy_score doesn't work with multilabel output, you need to use some other metric
#     # One possibility is average accuracy per class
#     accuracy_train = np.mean([accuracy_score(Y_train[:, i], y_pred_train[:, i]) for i in range(Y_train.shape[1])])
#     accuracy_test = np.mean([accuracy_score(Y_test[:, i], y_pred_test[:, i]) for i in range(Y_test.shape[1])])
#     accuracy_scores_train.append(accuracy_train)
#     accuracy_scores_test.append(accuracy_test)
    
# # Aggregate the evaluation results across folds
# mean_accuracy_train = np.mean(accuracy_scores_train)
# mean_accuracy_test = np.mean(accuracy_scores_test)
# print(f'Mean training accuracy over {kf.n_splits} folds: {mean_accuracy_train:.6f}')
# print(f'Mean testing accuracy over {kf.n_splits} folds: {mean_accuracy_test:.6f}')
# Out:
# Epoch 1/1000
# 35/35 [==============================] - 1s 14ms/step - loss: 1.6128 - accuracy: 0.2000 - val_loss: 1.6077 - val_accuracy: 0.3333
# Epoch 2/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.6076 - accuracy: 0.3143 - val_loss: 1.6014 - val_accuracy: 0.3333
# Epoch 3/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.5999 - accuracy: 0.3714 - val_loss: 1.5888 - val_accuracy: 0.4444
# Epoch 4/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.5845 - accuracy: 0.3143 - val_loss: 1.5695 - val_accuracy: 0.3333
# Epoch 5/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.5627 - accuracy: 0.3429 - val_loss: 1.5337 - val_accuracy: 0.5556
# Epoch 6/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.5285 - accuracy: 0.4286 - val_loss: 1.4909 - val_accuracy: 0.5556
# Epoch 7/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.4854 - accuracy: 0.4286 - val_loss: 1.4368 - val_accuracy: 0.5556
# Epoch 8/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.4355 - accuracy: 0.4286 - val_loss: 1.3675 - val_accuracy: 0.5556
# Epoch 9/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.3802 - accuracy: 0.4286 - val_loss: 1.3016 - val_accuracy: 0.5556
# Epoch 10/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.3283 - accuracy: 0.4286 - val_loss: 1.2435 - val_accuracy: 0.5556
# Epoch 11/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.2761 - accuracy: 0.4286 - val_loss: 1.1760 - val_accuracy: 0.5556
# Epoch 12/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.2356 - accuracy: 0.4286 - val_loss: 1.1160 - val_accuracy: 0.5556
# Epoch 13/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.1929 - accuracy: 0.4286 - val_loss: 1.0786 - val_accuracy: 0.5556
# Epoch 14/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.1627 - accuracy: 0.4286 - val_loss: 1.0366 - val_accuracy: 0.5556
# Epoch 15/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 1.1356 - accuracy: 0.4286 - val_loss: 1.0023 - val_accuracy: 0.5556
# Epoch 16/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.1145 - accuracy: 0.4286 - val_loss: 0.9779 - val_accuracy: 0.5556
# Epoch 17/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0942 - accuracy: 0.4286 - val_loss: 0.9589 - val_accuracy: 0.5556
# Epoch 18/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0795 - accuracy: 0.4286 - val_loss: 0.9415 - val_accuracy: 0.5556
# Epoch 19/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0651 - accuracy: 0.4571 - val_loss: 0.9251 - val_accuracy: 0.5556
# Epoch 20/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0508 - accuracy: 0.4571 - val_loss: 0.9080 - val_accuracy: 0.5556
# Epoch 21/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 1.0411 - accuracy: 0.4571 - val_loss: 0.8925 - val_accuracy: 0.5556
# Epoch 22/1000
# 35/35 [==============================] - 0s 4ms/step - loss:
1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4523 - accuracy: 0.9429 - val_loss: 0.5915 - val_accuracy: 0.8889
# Epoch 157/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4508 - accuracy: 0.9429 - val_loss: 0.5932 - val_accuracy: 0.8889
# Epoch 158/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4504 - accuracy: 0.9429 - val_loss: 0.5920 - val_accuracy: 0.8889
# Epoch 159/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4493 - accuracy: 0.9429 - val_loss: 0.5934 - val_accuracy: 0.8889
# Epoch 160/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4475 - accuracy: 0.9429 - val_loss: 0.5931 - val_accuracy: 0.8889
# Epoch 161/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4456 - accuracy: 0.9429 - val_loss: 0.5936 - val_accuracy: 0.8889
# Epoch 162/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4448 - accuracy: 0.9429 - val_loss: 0.5929 - val_accuracy: 0.8889
# Epoch 163/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4433 - accuracy: 0.9429 - val_loss: 0.5954 - val_accuracy: 0.8889
# Epoch 164/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4425 - accuracy: 0.9429 - val_loss: 0.5968 - val_accuracy: 0.8889
# Epoch 165/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4401 - accuracy: 0.9429 - val_loss: 0.5955 - val_accuracy: 0.8889
# Epoch 166/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4379 - accuracy: 0.9429 - val_loss: 0.5959 - val_accuracy: 0.8889
# Epoch 167/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4390 - accuracy: 0.9429 - val_loss: 0.5950 - val_accuracy: 0.8889
# Epoch 168/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4361 - accuracy: 0.9429 - val_loss: 0.5995 - val_accuracy: 0.8889
# Epoch 169/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4346 - accuracy: 0.9429 - val_loss: 0.5941 - val_accuracy: 0.8889
# Epoch 170/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4329 - accuracy: 0.9429 - val_loss: 0.5953 - val_accuracy: 0.8889
# Epoch 171/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4316 - accuracy: 0.9429 - val_loss: 0.5948 - val_accuracy: 0.8889
# Epoch 172/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4303 - accuracy: 0.9429 - val_loss: 0.5945 - val_accuracy: 0.8889
# Epoch 173/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4287 - accuracy: 0.9429 - val_loss: 0.5966 - val_accuracy: 0.8889
# Epoch 174/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4276 - accuracy: 0.9429 - val_loss: 0.5974 - val_accuracy: 0.8889
# Epoch 175/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4258 - accuracy: 0.9429 - val_loss: 0.5944 - val_accuracy: 0.8889
# Epoch 176/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4251 - accuracy: 0.9429 - val_loss: 0.5961 - val_accuracy: 0.8889
# Epoch 177/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4235 - accuracy: 0.9429 - val_loss: 0.5971 - val_accuracy: 0.8889
# Epoch 178/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4233 - accuracy: 0.9429 - val_loss: 0.5986 - val_accuracy: 0.8889
# Epoch 179/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4212 - accuracy: 0.9429 - val_loss: 0.5966 - val_accuracy: 0.8889
# Epoch 180/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4200 - accuracy: 0.9429 - val_loss: 0.5971 - val_accuracy: 0.8889
# Epoch 181/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4186 - accuracy: 0.9429 - val_loss: 0.5972 - val_accuracy: 0.8889
# Epoch 182/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4183 - accuracy: 0.9429 - val_loss: 0.5981 - val_accuracy: 0.8889
# Epoch 183/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4160 - accuracy: 0.9429 - val_loss: 0.5972 - val_accuracy: 0.8889
# Epoch 184/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4153 - accuracy: 0.9429 - val_loss: 0.5998 - val_accuracy: 0.8889
# Epoch 185/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4138 - accuracy: 0.9429 - val_loss: 0.5985 - val_accuracy: 0.8889
# Epoch 186/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4130 - accuracy: 0.9429 - val_loss: 0.5953 - val_accuracy: 0.8889
# Epoch 187/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4117 - accuracy: 0.9429 - val_loss: 0.5992 - val_accuracy: 0.8889
# Epoch 188/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4110 - accuracy: 0.9429 - val_loss: 0.6013 - val_accuracy: 0.8889
# Epoch 189/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4099 - accuracy: 0.9429 - val_loss: 0.5997 - val_accuracy: 0.8889
# Epoch 190/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4081 - accuracy: 0.9429 - val_loss: 0.5968 - val_accuracy: 0.8889
# Epoch 191/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4085 - accuracy: 0.9429 - val_loss: 0.6031 - val_accuracy: 0.8889
# Epoch 192/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.9429 - val_loss: 0.5998 - val_accuracy: 0.8889
# Epoch 193/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4051 - accuracy: 0.9429 - val_loss: 0.6028 - val_accuracy: 0.8889
# Epoch 194/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4055 - accuracy: 0.9429 - val_loss: 0.6029 - val_accuracy: 0.8889
# Epoch 195/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4033 - accuracy: 0.9429 - val_loss: 0.6023 - val_accuracy: 0.8889
# Epoch 196/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4021 - accuracy: 0.9429 - val_loss: 0.6044 - val_accuracy: 0.8889
# Epoch 197/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4001 - accuracy: 0.9429 - val_loss: 0.6039 - val_accuracy: 0.8889
# Epoch 198/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3990 - accuracy: 0.9429 - val_loss: 0.6048 - val_accuracy: 0.8889
# Epoch 199/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3984 - accuracy: 0.9429 - val_loss: 0.6031 - val_accuracy: 0.8889
# Epoch 200/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3969 - accuracy: 0.9429 - val_loss: 0.6009 - val_accuracy: 0.8889
# Epoch 201/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3962 - accuracy: 0.9429 - val_loss: 0.6076 - val_accuracy: 0.8889
# Epoch 202/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3967 - accuracy: 0.9429 - val_loss: 0.6036 - val_accuracy: 0.8889
# Epoch 203/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3933 - accuracy: 0.9429 - val_loss: 0.6077 - val_accuracy: 0.8889
# Epoch 204/1000
# 35/35 [==============================] - 0s 5ms/step - loss: 0.3924 - accuracy: 0.9429 - val_loss: 0.6068 - val_accuracy: 0.8889
# Epoch 205/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3906 - accuracy: 0.9429 - val_loss: 0.6060 - val_accuracy: 0.8889
# Epoch 206/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3894 - accuracy: 0.9429 - val_loss: 0.6090 - val_accuracy: 0.8889
# Epoch 207/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3883 - accuracy: 0.9429 - val_loss: 0.6069 - val_accuracy: 0.8889
# Epoch 208/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3875 - accuracy: 0.9429 - val_loss: 0.6124 - val_accuracy: 0.8889
# Epoch 209/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3863 - accuracy: 0.9429 - val_loss: 0.6073 - val_accuracy: 0.8889
# Epoch 210/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3848 - accuracy: 0.9429 - val_loss: 0.6090 - val_accuracy: 0.8889
# Epoch 211/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3842 - accuracy: 0.9429 - val_loss: 0.6114 - val_accuracy: 0.8889
# Epoch 212/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3833 - accuracy: 0.9429 - val_loss: 0.6110 - val_accuracy: 0.8889
# Epoch 213/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3816 - accuracy: 0.9429 - val_loss: 0.6086 - val_accuracy: 0.8889
# Epoch 214/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3800 - accuracy: 0.9429 - val_loss: 0.6088 - val_accuracy: 0.8889
# Epoch 215/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3795 - accuracy: 0.9429 - val_loss: 0.6092 - val_accuracy: 0.8889
# Epoch 216/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3783 - accuracy: 0.9429 - val_loss: 0.6113 - val_accuracy: 0.8889
# Epoch 217/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3773 - accuracy: 0.9429 - val_loss: 0.6106 - val_accuracy: 0.8889
# Epoch 218/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.3751 - accuracy: 0.9429 - val_loss: 0.6125 - val_accuracy: 0.8889
# Epoch 219/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3749 - accuracy: 0.9429 - val_loss: 0.6121 - val_accuracy: 0.8889
# Epoch 220/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3735 - accuracy: 0.9429 - val_loss: 0.6140 - val_accuracy: 0.8889
# Epoch 221/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3728 - accuracy: 0.9429 - val_loss: 0.6126 - val_accuracy: 0.8889
# Epoch 222/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3714 - accuracy: 0.9429 - val_loss: 0.6143 - val_accuracy: 0.8889
# Epoch 223/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3705 - accuracy: 0.9429 - val_loss: 0.6158 - val_accuracy: 0.8889
# Epoch 224/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3696 - accuracy: 0.9429 - val_loss: 0.6151 - val_accuracy: 0.8889
# Epoch 225/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3690 - accuracy: 0.9429 - val_loss: 0.6167 - val_accuracy: 0.8889
# Epoch 226/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3674 - accuracy: 0.9429 - val_loss: 0.6203 - val_accuracy: 0.8889
# Epoch 227/1000
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3665 - accuracy: 0.9429 - val_loss: 0.6164 - val_accuracy: 0.8889
# Epoch 228/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3656 - accuracy: 0.9429 - val_loss: 0.6187 - val_accuracy: 0.8889
# Epoch 229/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3643 - accuracy: 0.9429 - val_loss: 0.6199 - val_accuracy: 0.8889
# Epoch 230/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3633 - accuracy: 0.9429 - val_loss: 0.6217 - val_accuracy: 0.8889
# Epoch 231/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.9429 - val_loss: 0.6198 - val_accuracy: 0.8889
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 35ms/step
# Epoch 1/1000
# 35/35 [==============================] - 0s 6ms/step - loss: 0.4343 - accuracy: 0.9143 - val_loss: 0.3391 - val_accuracy: 1.0000
# Epoch 2/1000
# 35/35 [==============================] - 0s 4ms/step - loss: 0.4234 - accuracy: 0.9143 - val_loss: 0.3416 - val_accuracy: 1.0000
# Epoch 3/1000
# 25/35 [====================>.........] - ETA: 0s - loss: 0.3894 - accuracy: 0.9200

# %%
# model_prod = create_keras_model(n_features, n_classes, hidden_nodes=[[6, 3], [5, 3], [5, 4]],
#                                 optimizer='adam', learning_rate=0.001, regularization_factor=0.01)

# # Define early stopping callback
# early_stop_prod = EarlyStopping(monitor='val_loss', patience=100)
# # Train the model
# model_prod_fit = model_prod.fit(X_train, Y_train, validation_data=(X_test, Y_test), verbose=1, batch_size=1, epochs=1000, callbacks=[early_stop_prod])

# %%
# maxes = []
# for met in model_prod_fit.history.keys():
#     maxes.append(max(model_prod_fit.history[met]))
# mmax = max(maxes)

# pd.DataFrame(model_prod_fit.history).plot(figsize=(9, 5))
# plt.grid(True)
# plt.gca().set_ylim(0, 1.05*mmax)
# plt.xlabel('Epochs')
# plt.ylabel('Loss / Accuracy')
# plt.title('Production Model')
# plt.show()

# %%
maxes = []
for met in model_fit.history.keys():
    maxes.append(max(model_fit.history[met]))
mmax = max(maxes)

pd.DataFrame(model_fit.history).plot(figsize=(9, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1.05*mmax)
plt.xlabel('Epochs')
plt.ylabel('Loss / Accuracy')
plt.title('Production Model')
plt.show()

# %%
# # learning_rates = [0.001, 0.01, 0.05, 0.1, 0.5, 1]
# # regularization_factors = [0.3, 0.25, 0.2, 0.15, 0.1, 0.5, 0.01, 0.05, 0.001, 0.0005]
# learning_rates = [0.0005, 0.001, 0.005 ,0.01, 0.02]
# regularization_factors = [0.05, 0.01, 0.05, 0.001, 0.0005, 0.0001]
# # Initialize dictionary to hold results
# results = {}

# for lr in learning_rates:
#     for rf in regularization_factors:
#         # Create and train the model
#         model = create_keras_model(n_features, n_classes, hidden_nodes=[[6, 3], [5, 3], [5, 4]], 
#                                    optimizer='adam', learning_rate=lr, regularization_factor=rf)
#         early_stop = EarlyStopping(monitor='val_loss', patience=50)
#         history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), verbose=1, batch_size=1, epochs=1000, callbacks=[early_stop])

#         # Store the results
#         results[(lr, rf)] = {
#             'accuracy': max(history.history['accuracy']),
#             'loss': min(history.history['loss']),
#             'val_accuracy': max(history.history['val_accuracy']),
#             'val_loss': min(history.history['val_loss'])
#         }

# %%
# import seaborn as sns

# # Reshape accuracy results into a matrix
# accuracy_results = np.zeros((len(learning_rates), len(regularization_factors)))
# for i, lr in enumerate(learning_rates):
#     for j, rf in enumerate(regularization_factors):
#         accuracy_results[i, j] = results[(lr, rf)]['accuracy']

# # Create a heatmap
# plt.figure(figsize=(10, 4))
# sns.heatmap(accuracy_results, annot=True, fmt=".4f", xticklabels=regularization_factors, yticklabels=learning_rates)
# plt.title('Accuracy')
# plt.xlabel('Regularization Factor')
# plt.ylabel('Learning Rate')
# plt.show()

# %%
# skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# accuracy_scores_train = []
# accuracy_scores_test = []

# for train_index, test_index in skf.split(X, y):
#     X_train, X_test = X[train_index], X[test_index]
#     Y_train, Y_test = Y[train_index], Y[test_index]
    
#     # Define early stopping callback
#     early_stop = EarlyStopping(monitor='val_loss', patience=100)
#     # Train the model
#     model_fit = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), verbose=1, batch_size=1, epochs=1000, callbacks=[early_stop])
    
#     # Test your model on the testing set
#     Y_pred_train = model.predict(X_train)
#     Y_pred_test = model.predict(X_test)
    
#     # Convert the prediction probabilities into class predictions
#     Y_pred_train = (Y_pred_train > 0.5).astype(int)
#     Y_pred_test = (Y_pred_test > 0.5).astype(int)
    
    
#     # Evaluate the model's performance on training and testing set
#     accuracy_train = np.mean([accuracy_score(Y_train[:, i], Y_pred_train[:, i]) for i in range(Y_train.shape[1])])
#     accuracy_test = np.mean([accuracy_score(Y_test[:, i], Y_pred_test[:, i]) for i in range(Y_test.shape[1])])
#     accuracy_scores_train.append(accuracy_train)
#     accuracy_scores_test.append(accuracy_test)
    
# # Aggregate the evaluation results across folds
# mean_accuracy_train = np.mean(accuracy_scores_train)
# mean_accuracy_test = np.mean(accuracy_scores_test)
# print(f'Mean training accuracy over {skf.n_splits} folds: {mean_accuracy_train:.6f}')
# print(f'Mean testing accuracy over {skf.n_splits} folds: {mean_accuracy_test:.6f}')

# %%
# # get predictions
# y_pred = grid.predict(X_test)

# # get accuracy
# acc = accuracy_score(Y_test, y_pred)

# # print accuracy
# print('Accuracy:', acc)

# # print best parameters
# print('Best Parameters:', grid.best_params_)


from sklearn.metrics import confusion_matrix

# predict classes for test set
Y_pred = model_prod.predict(X_test)
y_pred = np.argmax(Y_pred, axis=1)

# convert one-hot encoded test labels back to class labels
y_true = np.argmax(Y_test, axis=1)

# calculate confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(3, 3))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, xticklabels=types, yticklabels=types)
plt.xlabel('Predicted')
plt.ylabel('True')
# plt.title('Confusion Matrix - Testing Set')
plt.show()
# Out:
# 2/2 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Specify the labels for the axes
labels = types

# Specify the values for the confusion matrix
confusion_matrix = np.array([
    [10, 0, 0, 0, 0],
    [0, 9, 0, 1, 0],
    [0, 0, 10, 0, 0],
    [0, 2, 0, 5, 0],
    [0, 0, 0, 0, 7]
])

plt.figure(figsize=(3, 3))

sns.heatmap(confusion_matrix, annot=True, cmap='Blues', fmt='g', cbar=False, xticklabels=labels, yticklabels=labels)

# plt.title('Confusion Matrix - Testing Set')
plt.xlabel('Predicted')
plt.ylabel('True')

plt.show()

# %%
from sklearn.metrics import classification_report

# print classification report
print(classification_report(y_true, y_pred, target_names=types))
# Out:
#               precision    recall  f1-score   support
#
#           PO       0.83      1.00      0.91        10
#           SL       0.70      0.70      0.70        10
#           LP       1.00      0.90      0.95        10
#           LF       0.60      0.43      0.50         7
#           CR       0.88      1.00      0.93         7
#
#     accuracy                           0.82        44
#    macro avg       0.80      0.81      0.80        44
# weighted avg       0.81      0.82      0.81        44

# %%
end_time = time.time()
print(f'Total runtime of this notebook is {(end_time-start_time)/60:0.2f} minutes.')
