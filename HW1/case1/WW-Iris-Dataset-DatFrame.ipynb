# %%
import pandas as pd
import numpy as np
import operator

# visualization packages:
import seaborn as sns
import matplotlib.pyplot as plt

#from sklearn import datasets
from sklearn.datasets import load_iris

# %matplotlib inline

# %% [markdown]
# ## Load and explore the data

# %%
iris = load_iris()

# %%
# convert the dataset into a pandas dataframe (just a matter of taste!)
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# %%
# rename the columns: 
iris_features = ["sepal_length", "sepal_width", "petal_length", "petal_width"]
iris_df.columns = iris_features

# %%
# add the target (output) column, currently nominal in [0,1,2]:
iris_df["target"] = iris.target
# get the real names of the target classes:
target_names = iris.target_names
print(target_names)
# add a target column with the target names
iris_df['species'] = iris_df['target']
# change the 0, 1, 2 coding to the species name:
iris_df['species'].replace([0, 1, 2], target_names, inplace=True)
iris_df.head()
# Out:
# ['setosa' 'versicolor' 'virginica']
#    sepal_length  sepal_width  petal_length  petal_width  target species
# 0           5.1          3.5           1.4          0.2       0  setosa
# 1           4.9          3.0           1.4          0.2       0  setosa
# 2           4.7          3.2           1.3          0.2       0  setosa
# 3           4.6          3.1           1.5          0.2       0  setosa
# 4           5.0          3.6           1.4          0.2       0  setosa

# %%
# Check the data type of each field:
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   target        150 non-null    int64
#  5   species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
sns.pairplot(iris_df, 
             vars = iris_df.columns[0:4], 
             hue='species', 
             palette='husl'
            )

# %% [markdown]
# ## General methods implemented by the `sklearn` models
#
# ```python
# # fit a model:
# fit(X, y[, sample_weight])
# # predict classes:
# predict(X)
# # predict log probability:
# predict_log_proba(X)
# # predict probability:
# predict_proba(X)
# # get accuracy (the mean accuracy):
# score(X, y[, sample_weight])
# ```
